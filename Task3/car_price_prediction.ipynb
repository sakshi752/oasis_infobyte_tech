# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('CarPrice.csv')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
print("size= ",df.size)
print("dimensions= ",df.shape)
print(df.dtypes)
# Out:
# size=  5330
# dimensions=  (205, 26)
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df['CarName'].unique().size #so there is info for 147 different cars
# Out:
# 147

# %%
list(df.columns)
# Out:
# ['car_ID',
#  'symboling',
#  'CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginetype',
#  'cylindernumber',
#  'enginesize',
#  'fuelsystem',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
# calculate correlation matrix with dependent feature
corr_matrix_with_price = df.corr()


# create heatmap with dependent feature using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_with_price, annot=True)
plt.title('Correlation Matrix with Price Heatmap')
plt.show()
# Out:
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_9180\2000000116.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix_with_price = df.corr()

# %%
corr_matrix_with_price=corr_matrix_with_price['price'].abs().sort_values(ascending=False)
print("Features which are highly correlated to car price in positive direction ")
print(corr_matrix_with_price[corr_matrix_with_price>0.66])
# Out:
# Features which are highly correlated to car price in positive direction
# price         1.000000
# enginesize    0.874145
# curbweight    0.835305
# horsepower    0.808139
# carwidth      0.759325
# highwaympg    0.697599
# citympg       0.685751
# carlength     0.682920
# Name: price, dtype: float64

# %% [markdown]
# # avoid multicollinearity
# - now let's see what feature are highly correlated to each otherr so that we can select features efficiently

# %%
# calculate correlation matrix without dependent feature
corr_matrix_without_price = df.iloc[:,:-1].corr()
# create heatmap without dependent feature using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_without_price, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix without Price Heatmap')
plt.show()
# Out:
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_9180\4079673126.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix_without_price = df.iloc[:,:-1].corr()

# %% [markdown]
# - remove correlated features and they can't be removed wrt to dependent feature
# - let's suppose some features are highly correlated then we can say that those features do same task. Hence we can drop one of feature.

# %%
thresh=0.83

# %%
def correlation(df,thresh):
    col_corr=set() #set of all the names of correlated cols
    corr_matrix=df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>thresh:
                colname=corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
# features which are highly correlated
correlation(df.iloc[:,:-1],thresh)
# Out:
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_9180\1198058523.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=df.corr()
# {'carlength', 'carwidth', 'curbweight', 'enginesize', 'highwaympg'}

# %% [markdown]
# - conclusion: below pairs of features are highly correlated so any one of them can be selected in final df

# %%
print(corr_matrix_without_price.loc['carlength','carwidth'])
print(corr_matrix_without_price.loc['curbweight','enginesize'])
print(corr_matrix_without_price.loc['curbweight','highwaympg'])
# Out:
# 0.8411182684818453
# 0.850594073426277
# -0.7974647922811803

# %%
final_df=df[['fueltype', 'aspiration', 'carbody', 'drivewheel', 'carwidth','curbweight', 'enginetype', 'cylindernumber','price']]
final_df.tail()
# Out:
#     fueltype aspiration carbody drivewheel  carwidth  curbweight enginetype  \
# 200      gas        std   sedan        rwd      68.9        2952        ohc
# 201      gas      turbo   sedan        rwd      68.8        3049        ohc
# 202      gas        std   sedan        rwd      68.9        3012       ohcv
# 203   diesel      turbo   sedan        rwd      68.9        3217        ohc
# 204      gas      turbo   sedan        rwd      68.9        3062        ohc
#
#     cylindernumber    price
# 200           four  16845.0
# 201           four  19045.0
# 202            six  21485.0
# 203            six  22470.0
# 204           four  22625.0

# %%
for col in final_df.columns:
    count=df[col].value_counts()
    print(f"Val counts of {col}")
    print(count)
    print()
# Out:
# Val counts of fueltype
# gas       185
# diesel     20
# Name: fueltype, dtype: int64
#
# Val counts of aspiration
# std      168
# turbo     37
# Name: aspiration, dtype: int64
#
# Val counts of carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64
#
# Val counts of drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64
#
# Val counts of carwidth
# 63.8    24
# 66.5    23
# 65.4    15
# 63.6    11
# 64.4    10
# 68.4    10
# 64.0     9
# 65.5     8
# 65.2     7
# 64.2     6
# 66.3     6
# 65.6     6
# 67.2     6
# 67.9     5
# 66.9     5
# 65.7     4
# 68.9     4
# 64.8     4
# 63.9     3
# 70.3     3
# 71.7     3
# 71.4     3
# 65.0     3
# 68.3     2
# 67.7     2
# 64.1     2
# 66.1     2
# 69.6     2
# 64.6     2
# 72.0     1
# 68.0     1
# 70.5     1
# 61.8     1
# 66.0     1
# 62.5     1
# 70.6     1
# 72.3     1
# 66.6     1
# 63.4     1
# 60.3     1
# 70.9     1
# ...

# %%
final_df.replace({'fueltype':{'gas':0, 'diesel':1}},inplace = True)
final_df.replace({'aspiration':{'std':0, 'turbo':1}},inplace = True)
final_df.replace({'carbody':{'sedan':0, 'hatchback':1,'wagon':2,'hardtop':3,'convertible':4}},inplace = True)
final_df.replace({'drivewheel':{'fwd':0, 'rwd':1,'4wd':2}},inplace = True)
final_df.replace({'enginetype':{'ohc':0, 'ohcf':1,'ohcv':2, 'dohc':3,'l':4, 'rotor':5,'dohcv':6}},inplace = True)
final_df.replace({'cylindernumber':{'four':0, 'six':1,'five':2, 'eight':3,'two':4, 'three':5,'twelve':6}},inplace = True)
# Out:
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_9180\1908231739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.replace({'fueltype':{'gas':0, 'diesel':1}},inplace = True)
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_9180\1908231739.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.replace({'aspiration':{'std':0, 'turbo':1}},inplace = True)
# C:\Users\Sakshi\AppData\Local\Temp\ipykernel_9180\1908231739.py:3: SettingWithCopyWarning:
# ...

# %%
final_df.head()
# Out:
#    fueltype  aspiration  carbody  drivewheel  carwidth  curbweight  \
# 0         0           0        4           1      64.1        2548
# 1         0           0        4           1      64.1        2548
# 2         0           0        1           1      65.5        2823
# 3         0           0        0           0      66.2        2337
# 4         0           0        0           2      66.4        2824
#
#    enginetype  cylindernumber    price
# 0           3               0  13495.0
# 1           3               0  16500.0
# 2           2               1  16500.0
# 3           0               0  13950.0
# 4           0               2  17450.0

# %%
X=final_df.drop('price',axis=1)
y=final_df['price']

# %%
from sklearn.model_selection import train_test_split
# dividing the dataset in training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.26)
# determining the shapes of training and testing sets
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (151, 8)
# (151,)
# (54, 8)
# (54,)

# %% [markdown]
# 1. linear regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred_lr = lr.predict(X_test)
accuracy_lr = lr.score(X_test, y_test)
print("Linear Regression Accuracy:", accuracy_lr)
# Out:
# Linear Regression Accuracy: 0.7367534381433829

# %% [markdown]
# 2. random forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
y_pred_rf=rf.predict(X_test)
accuracy_rf=r2_score(y_test,y_pred_rf) 
accuracy_rf
# Out:
# 0.8475365335052233
